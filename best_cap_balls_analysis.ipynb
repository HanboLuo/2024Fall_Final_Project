# %%
from best_cap_analysis import *

# Analyze conditions for all Pokémon in the list
for pokemon in pokemon_list:
    analyze_conditions(pokemon, pokeballs)
# Out:
# Analyzing capture strategy for Mewtwo at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 1.88% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 0.86% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 1.20% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 1.65% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 1.40% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 1.51% (Full HP)
# Analyzing capture strategy for Mewtwo at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 3.34% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 3.40% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 4.98% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 6.78% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 6.93% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 6.42% (Low HP & Paralysis)
# Analyzing capture strategy for Pikachu at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 100.00% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 49.69% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 74.16% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 99.32% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 99.41% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 99.39% (Full HP)
# Analyzing capture strategy for Pikachu at low HP with paralysis:
# Turn 1: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 10: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 20: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 30: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 40: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 50: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Analyzing capture strategy for Charizard at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.79% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 11.97% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.18% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.52% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.52% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.47% (Full HP)
# Analyzing capture strategy for Charizard at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 49.00% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 49.22% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 74.38% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.86% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.86% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.77% (Low HP & Paralysis)
# Analyzing capture strategy for Snorlax at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 16.24% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 6.44% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 9.63% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 12.77% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 13.21% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 13.59% (Full HP)
# Analyzing capture strategy for Snorlax at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 26.97% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 27.22% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 40.53% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 54.82% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 54.57% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 55.12% (Low HP & Paralysis)
# Analyzing capture strategy for Gyarados at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.42% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 12.02% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.79% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.67% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.83% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.23% (Full HP)
# Analyzing capture strategy for Gyarados at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 48.94% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 49.30% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 74.42% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.79% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.89% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.80% (Low HP & Paralysis)
# Analyzing capture strategy for Gengar at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.09% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 12.12% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 18.00% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 24.02% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 22.91% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.76% (Full HP)
# Analyzing capture strategy for Gengar at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 49.45% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 49.61% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 73.72% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.79% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.93% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.77% (Low HP & Paralysis)
# Analyzing capture strategy for Dragonite at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.81% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 11.85% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.28% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.98% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.86% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.16% (Full HP)
# Analyzing capture strategy for Dragonite at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 48.60% (Low HP & Paralysis)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 49.29% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 74.40% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.85% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.83% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.95% (Low HP & Paralysis)
