# %%
import random
from init import *
import matplotlib.pyplot as plt
from function import *

def simulate_capture_by_turn(pokemon, pokeballs, num_simulations=20000, max_turns=50):
    turn_results = {turn: {} for turn in range(1, max_turns + 1)}

    for turn in range(1, max_turns + 1):
        for pokeball in pokeballs:
            # Skip Quick Ball if Pokémon is not at full HP and it's not turn 1
            if pokemon.current_hp < pokemon.max_hp and pokeball.name == 'Quick Ball':
                continue

            successes = 0
            for _ in range(num_simulations):
                if random.random() < calculate_catch_rate(pokemon, pokeball, turn):
                    successes += 1
            success_rate = successes / num_simulations
            turn_results[turn][pokeball.name] = success_rate

    return turn_results

def find_best_strategy(turn_results):
    best_strategy = {}
    for turn, results in turn_results.items():
        if results:  # Ensure there are results for this turn
            best_ball = max(results, key=results.get)
            best_strategy[turn] = (best_ball, results[best_ball])
    return best_strategy

def plot_dynamic_results(turn_results, pokemon):
    plt.figure(figsize=(12, 6))

    all_balls = set(ball for results in turn_results.values() for ball in results)
    for pokeball in all_balls:
        rates = [turn_results[turn].get(pokeball, 0) for turn in turn_results]
        plt.plot(range(1, len(turn_results) + 1), rates, label=pokeball)

    plt.title(f"Dynamic Capture Rates for {pokemon.name}")
    plt.xlabel("Turn")
    plt.ylabel("Capture Rate")
    plt.legend()
    plt.grid(True)
    plt.show()
def analyze_conditions(pokemon, pokeballs, num_simulations=20000, max_turns=50):
    # Full HP analysis
    pokemon.current_hp = pokemon.max_hp  # Full HP
    pokemon.status = None
    print(f"\nAnalyzing capture strategy for {pokemon.name} at full HP:")
    turn_results_full_hp = simulate_capture_by_turn(pokemon, pokeballs, num_simulations, max_turns)
    best_strategy_full_hp = find_best_strategy(turn_results_full_hp)
    for turn, (ball, rate) in best_strategy_full_hp.items():
        if turn % 10 == 0 or turn == 1:
            print(f"Turn {turn}: Best Ball = {ball}, Capture Rate = {rate:.2%} (Full HP)")
    plot_dynamic_results(turn_results_full_hp, pokemon)

    # Low HP with paralysis
    pokemon.current_hp = pokemon.max_hp // 10  # Low HP
    pokemon.status = 'paralysis'
    print(f"\nAnalyzing capture strategy for {pokemon.name} at low HP with paralysis:")
    turn_results_low_hp = simulate_capture_by_turn(pokemon, pokeballs, num_simulations, max_turns)
    best_strategy_low_hp = find_best_strategy(turn_results_low_hp)
    for turn, (ball, rate) in best_strategy_low_hp.items():
        if turn % 10 == 0 or turn == 1:
            print(f"Turn {turn}: Best Ball = {ball}, Capture Rate = {rate:.2%} (Low HP & Paralysis)")
    plot_dynamic_results(turn_results_low_hp, pokemon)

for pokemon in pokemon_list:
    analyze_conditions(pokemon, pokeballs)
# Out:
# Analyzing capture strategy for Mewtwo at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 2.02% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 0.79% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 1.36% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 1.49% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 1.61% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 1.49% (Full HP)
# Analyzing capture strategy for Mewtwo at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 3.15% (Low HP & Paralysis)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 3.29% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 4.71% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 6.48% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 6.35% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 6.42% (Low HP & Paralysis)
# Analyzing capture strategy for Pikachu at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 100.00% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 49.79% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 74.24% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 99.25% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 99.20% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 99.28% (Full HP)
# Analyzing capture strategy for Pikachu at low HP with paralysis:
# Turn 1: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 10: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 20: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 30: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 40: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 50: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Analyzing capture strategy for Charizard at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.13% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 11.99% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.92% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.65% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.30% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.27% (Full HP)
# Analyzing capture strategy for Charizard at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 49.06% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 49.73% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 73.88% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.95% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.83% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.75% (Low HP & Paralysis)
# Analyzing capture strategy for Snorlax at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 16.37% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 6.49% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 9.37% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 13.32% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 13.00% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 12.88% (Full HP)
# Analyzing capture strategy for Snorlax at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 27.68% (Low HP & Paralysis)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 27.37% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 40.91% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 55.86% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 54.75% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 55.08% (Low HP & Paralysis)
# Analyzing capture strategy for Gyarados at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.67% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 11.87% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.62% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 24.10% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.31% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.31% (Full HP)
# Analyzing capture strategy for Gyarados at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 49.66% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 50.04% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 74.13% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.80% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.89% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.78% (Low HP & Paralysis)
# Analyzing capture strategy for Gengar at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 28.99% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 11.68% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 16.79% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.27% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.23% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.71% (Full HP)
# Analyzing capture strategy for Gengar at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 49.11% (Low HP & Paralysis)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 49.30% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 74.25% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.80% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.95% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.80% (Low HP & Paralysis)
# Analyzing capture strategy for Dragonite at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.35% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 11.95% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 18.10% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.59% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.91% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.51% (Full HP)
# Analyzing capture strategy for Dragonite at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 49.48% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 50.19% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 73.70% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.80% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.88% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.87% (Low HP & Paralysis)
