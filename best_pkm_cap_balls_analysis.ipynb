# %%
from function import *
import matplotlib.pyplot as plt
import random

def simulate_capture_by_turn(pokemon, pokeballs, num_simulations=20000, max_turns=50):
    """
    Simulate capture success rates by turn for a Pokémon using various Poké Balls.

    Parameters:
    - pokemon (Pokemon): The Pokémon to capture.
    - pokeballs (list of PokeBall): A list of Poké Balls to evaluate.
    - num_simulations (int): Number of simulations to perform per turn (default 20,000).
    - max_turns (int): Maximum number of turns to simulate (default 50).

    Returns:
    - dict: Nested dictionary where keys are turns, and values are dictionaries 
            with Poké Ball names and their corresponding capture rates.
    """
    turn_results = {turn: {} for turn in range(1, max_turns + 1)}

    for turn in range(1, max_turns + 1):
        for pokeball in pokeballs:
            # Skip Quick Ball if Pokémon is not at full HP and it's not turn 1
            if pokemon.current_hp < pokemon.max_hp and pokeball.name == 'Quick Ball':
                continue

            successes = 0
            for _ in range(num_simulations):
                if random.random() < calculate_catch_rate(pokemon, pokeball, turn):
                    successes += 1
            success_rate = successes / num_simulations
            turn_results[turn][pokeball.name] = success_rate

    return turn_results


def find_best_strategy(turn_results):
    """
    Identify the best capture strategy for each turn.

    Parameters:
    - turn_results (dict): Results from simulate_capture_by_turn, containing capture rates.

    Returns:
    - dict: Dictionary where keys are turns, and values are tuples of the best Poké Ball 
            and its corresponding capture rate.
    """
    best_strategy = {}
    for turn, results in turn_results.items():
        if results:  # Ensure there are results for this turn
            best_ball = max(results, key=results.get)
            best_strategy[turn] = (best_ball, results[best_ball])
    return best_strategy


def plot_dynamic_results(turn_results, pokemon):
    """
    Plot dynamic capture rates over turns for a given Pokémon.

    Parameters:
    - turn_results (dict): Results from simulate_capture_by_turn, containing capture rates.
    - pokemon (Pokemon): The Pokémon being analyzed.

    Returns:
    - None
    """
    plt.figure(figsize=(12, 6))

    all_balls = set(ball for results in turn_results.values() for ball in results)
    for pokeball in all_balls:
        rates = [turn_results[turn].get(pokeball, 0) for turn in turn_results]
        plt.plot(range(1, len(turn_results) + 1), rates, label=pokeball)

    plt.title(f"Dynamic Capture Rates for {pokemon.name}")
    plt.xlabel("Turn")
    plt.ylabel("Capture Rate")
    plt.legend()
    plt.grid(True)
    plt.show()


def analyze_conditions(pokemon, pokeballs, num_simulations=20000, max_turns=50):
    """
    Analyze capture strategies under different conditions (Full HP and Low HP with Paralysis).

    Parameters:
    - pokemon (Pokemon): The Pokémon to capture.
    - pokeballs (list of PokeBall): A list of Poké Balls to evaluate.
    - num_simulations (int): Number of simulations to perform per condition (default 20,000).
    - max_turns (int): Maximum number of turns to simulate (default 50).

    Returns:
    - None
    """
    # Full HP analysis
    pokemon.current_hp = pokemon.max_hp  # Full HP
    pokemon.status = None
    print(f"\nAnalyzing capture strategy for {pokemon.name} at full HP:")
    turn_results_full_hp = simulate_capture_by_turn(pokemon, pokeballs, num_simulations, max_turns)
    best_strategy_full_hp = find_best_strategy(turn_results_full_hp)
    for turn, (ball, rate) in best_strategy_full_hp.items():
        if turn % 10 == 0 or turn == 1:
            print(f"Turn {turn}: Best Ball = {ball}, Capture Rate = {rate:.2%} (Full HP)")
    plot_dynamic_results(turn_results_full_hp, pokemon)

    # Low HP with paralysis
    pokemon.current_hp = pokemon.max_hp // 10  # Low HP
    pokemon.status = 'paralysis'
    print(f"\nAnalyzing capture strategy for {pokemon.name} at low HP with paralysis:")
    turn_results_low_hp = simulate_capture_by_turn(pokemon, pokeballs, num_simulations, max_turns)
    best_strategy_low_hp = find_best_strategy(turn_results_low_hp)
    for turn, (ball, rate) in best_strategy_low_hp.items():
        if turn % 10 == 0 or turn == 1:
            print(f"Turn {turn}: Best Ball = {ball}, Capture Rate = {rate:.2%} (Low HP & Paralysis)")
    plot_dynamic_results(turn_results_low_hp, pokemon)


# Analyze conditions for all Pokémon in the list
for pokemon in pokemon_list:
    analyze_conditions(pokemon, pokeballs)
# Out:
# Analyzing capture strategy for Mewtwo at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 2.04% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 0.80% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 1.22% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 1.69% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 1.60% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 1.55% (Full HP)
# Analyzing capture strategy for Mewtwo at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 3.21% (Low HP & Paralysis)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 3.44% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 4.88% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 6.50% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 6.41% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 6.35% (Low HP & Paralysis)
# Analyzing capture strategy for Pikachu at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 100.00% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 49.86% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 74.74% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 99.33% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 99.21% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 99.37% (Full HP)
# Analyzing capture strategy for Pikachu at low HP with paralysis:
# Turn 1: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 10: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 20: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 30: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 40: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 50: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Analyzing capture strategy for Charizard at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.36% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 11.82% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.52% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.83% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.21% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.12% (Full HP)
# Analyzing capture strategy for Charizard at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 49.29% (Low HP & Paralysis)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 49.46% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 74.18% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.93% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.72% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.95% (Low HP & Paralysis)
# Analyzing capture strategy for Snorlax at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 16.16% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 6.49% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 9.89% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 13.03% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 12.84% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 13.14% (Full HP)
# Analyzing capture strategy for Snorlax at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 27.39% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 27.50% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 40.83% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 55.23% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 55.02% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 54.79% (Low HP & Paralysis)
# Analyzing capture strategy for Gyarados at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.58% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 11.82% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.63% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.39% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.73% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.58% (Full HP)
# Analyzing capture strategy for Gyarados at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 49.46% (Low HP & Paralysis)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 49.71% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 73.91% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.88% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.82% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.84% (Low HP & Paralysis)
# Analyzing capture strategy for Gengar at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.22% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 11.67% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.45% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.44% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.54% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.56% (Full HP)
# Analyzing capture strategy for Gengar at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 49.42% (Low HP & Paralysis)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 49.65% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 73.95% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.81% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.75% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.80% (Low HP & Paralysis)
# Analyzing capture strategy for Dragonite at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.35% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 11.74% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.32% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 24.10% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.86% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.45% (Full HP)
# Analyzing capture strategy for Dragonite at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 49.48% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 49.92% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 73.58% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.91% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.80% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.83% (Low HP & Paralysis)
