# %%
from function import *
import matplotlib.pyplot as plt
import random

def simulate_capture_by_turn(pokemon, pokeballs, num_simulations=20000, max_turns=50):
    """
    Simulate capture success rates by turn for a Pokémon using various Poké Balls.

    :param pokemon: The Pokémon being simulated.
    :param pokeballs: A list of Poké Balls to evaluate.
    :param num_simulations: Number of simulations to perform per turn (default 20,000).
    :param max_turns: Maximum number of turns to simulate (default 50).
    :return: A nested dictionary where keys are turns, and values are dictionaries 
             with Poké Ball names and their corresponding capture rates.

    Example:
    >>> simulate_capture_by_turn(pokemon_list[0], pokeballs, num_simulations=1000, max_turns=10)
    This will simulate the capture rates for Mewtwo over 10 turns using 1000 simulations for each ball.
    """
    turn_results = {turn: {} for turn in range(1, max_turns + 1)}

    for turn in range(1, max_turns + 1):
        for pokeball in pokeballs:
            # Skip Quick Ball if Pokémon is not at full HP and it's not turn 1
            if pokemon.current_hp < pokemon.max_hp and pokeball.name == 'Quick Ball':
                continue

            successes = 0
            for _ in range(num_simulations):
                if random.random() < calculate_catch_rate(pokemon, pokeball, turn):
                    successes += 1
            success_rate = successes / num_simulations
            turn_results[turn][pokeball.name] = success_rate

    return turn_results


def find_best_strategy(turn_results):
    """
    Identify the best capture strategy for each turn.

    :param turn_results: Results from simulate_capture_by_turn, containing capture rates.
    :return: A dictionary where keys are turns, and values are tuples of the best Poké Ball 
             and its corresponding capture rate.

    Example:
    >>> turn_results = {1: {"Quick Ball": 0.1, "Ultra Ball": 0.08}, 2: {"Timer Ball": 0.2}}
    >>> find_best_strategy(turn_results)
    This will return a dictionary indicating the best Poké Ball for each turn based on capture rate.
    """
    best_strategy = {}
    for turn, results in turn_results.items():
        if results:  # Ensure there are results for this turn
            best_ball = max(results, key=results.get)
            best_strategy[turn] = (best_ball, results[best_ball])
    return best_strategy


def plot_dynamic_results(turn_results, pokemon):
   """
    Plot dynamic capture rates over turns for a given Pokémon.

    :param turn_results: Results from simulate_capture_by_turn, containing capture rates.
    :param pokemon: The Pokémon being analyzed.
    :return: None

    Example:
    >>> turn_results = {1: {"Quick Ball": 0.1, "Ultra Ball": 0.08}, 2: {"Timer Ball": 0.2}}
    >>> plot_dynamic_results(turn_results, pokemon_list[0])
    This will generate a line plot showing the capture rate trends for each Poké Ball over time.
    """
    plt.figure(figsize=(12, 6))

    all_balls = set(ball for results in turn_results.values() for ball in results)
    for pokeball in all_balls:
        rates = [turn_results[turn].get(pokeball, 0) for turn in turn_results]
        plt.plot(range(1, len(turn_results) + 1), rates, label=pokeball)

    plt.title(f"Dynamic Capture Rates for {pokemon.name}")
    plt.xlabel("Turn")
    plt.ylabel("Capture Rate")
    plt.legend()
    plt.grid(True)
    plt.show()


def analyze_conditions(pokemon, pokeballs, num_simulations=20000, max_turns=50):
    """
    Analyze capture strategies under different conditions (Full HP and Low HP with Paralysis).

    :param pokemon: The Pokémon to capture.
    :param pokeballs: A list of Poké Balls to evaluate.
    :param num_simulations: Number of simulations to perform per condition (default 20,000).
    :param max_turns: Maximum number of turns to simulate (default 50).
    :return: None

    Example:
    >>> analyze_conditions(pokemon_list[0], pokeballs, num_simulations=1000, max_turns=10)
    This will analyze capture strategies for Mewtwo under Full HP and Low HP with Paralysis,
    and plot the results for each condition.
    """
    # Full HP analysis
    pokemon.current_hp = pokemon.max_hp  # Full HP
    pokemon.status = None
    print(f"\nAnalyzing capture strategy for {pokemon.name} at full HP:")
    turn_results_full_hp = simulate_capture_by_turn(pokemon, pokeballs, num_simulations, max_turns)
    best_strategy_full_hp = find_best_strategy(turn_results_full_hp)
    for turn, (ball, rate) in best_strategy_full_hp.items():
        if turn % 10 == 0 or turn == 1:
            print(f"Turn {turn}: Best Ball = {ball}, Capture Rate = {rate:.2%} (Full HP)")
    plot_dynamic_results(turn_results_full_hp, pokemon)

    # Low HP with paralysis
    pokemon.current_hp = pokemon.max_hp // 10  # Low HP
    pokemon.status = 'paralysis'
    print(f"\nAnalyzing capture strategy for {pokemon.name} at low HP with paralysis:")
    turn_results_low_hp = simulate_capture_by_turn(pokemon, pokeballs, num_simulations, max_turns)
    best_strategy_low_hp = find_best_strategy(turn_results_low_hp)
    for turn, (ball, rate) in best_strategy_low_hp.items():
        if turn % 10 == 0 or turn == 1:
            print(f"Turn {turn}: Best Ball = {ball}, Capture Rate = {rate:.2%} (Low HP & Paralysis)")
    plot_dynamic_results(turn_results_low_hp, pokemon)


# Analyze conditions for all Pokémon in the list
for pokemon in pokemon_list:
    analyze_conditions(pokemon, pokeballs)
# Out:
# Analyzing capture strategy for Mewtwo at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 1.93% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 0.77% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 1.18% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 1.49% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 1.58% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 1.57% (Full HP)
# Analyzing capture strategy for Mewtwo at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 3.42% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 3.30% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 4.76% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 6.44% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 6.68% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 6.50% (Low HP & Paralysis)
# Analyzing capture strategy for Pikachu at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 100.00% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 49.60% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 74.27% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 99.34% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 99.34% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 99.33% (Full HP)
# Analyzing capture strategy for Pikachu at low HP with paralysis:
# Turn 1: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 10: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 20: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 30: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 40: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Turn 50: Best Ball = Poke Ball, Capture Rate = 100.00% (Low HP & Paralysis)
# Analyzing capture strategy for Charizard at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.80% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 11.88% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.69% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.45% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.89% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.36% (Full HP)
# Analyzing capture strategy for Charizard at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 49.69% (Low HP & Paralysis)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 49.98% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 74.11% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.88% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.83% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.83% (Low HP & Paralysis)
# Analyzing capture strategy for Snorlax at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 16.37% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 6.65% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 9.79% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 13.03% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 13.21% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 13.12% (Full HP)
# Analyzing capture strategy for Snorlax at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 27.48% (Low HP & Paralysis)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 27.71% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 41.34% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 55.30% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 55.14% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 55.37% (Low HP & Paralysis)
# Analyzing capture strategy for Gyarados at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.75% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 11.83% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.91% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.86% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.36% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.80% (Full HP)
# Analyzing capture strategy for Gyarados at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 48.95% (Low HP & Paralysis)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 50.03% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 73.91% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.71% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.83% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.89% (Low HP & Paralysis)
# Analyzing capture strategy for Gengar at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.57% (Full HP)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 11.80% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.81% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.25% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 24.03% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.38% (Full HP)
# Analyzing capture strategy for Gengar at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 48.91% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 49.77% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 73.93% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.69% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.83% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.81% (Low HP & Paralysis)
# Analyzing capture strategy for Dragonite at full HP:
# Turn 1: Best Ball = Quick Ball, Capture Rate = 29.37% (Full HP)
# Turn 10: Best Ball = Ultra Ball, Capture Rate = 12.11% (Full HP)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 17.82% (Full HP)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 23.47% (Full HP)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 23.49% (Full HP)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 23.73% (Full HP)
# Analyzing capture strategy for Dragonite at low HP with paralysis:
# Turn 1: Best Ball = Ultra Ball, Capture Rate = 49.18% (Low HP & Paralysis)
# Turn 10: Best Ball = Timer Ball, Capture Rate = 49.54% (Low HP & Paralysis)
# Turn 20: Best Ball = Timer Ball, Capture Rate = 74.05% (Low HP & Paralysis)
# Turn 30: Best Ball = Timer Ball, Capture Rate = 98.69% (Low HP & Paralysis)
# Turn 40: Best Ball = Timer Ball, Capture Rate = 98.69% (Low HP & Paralysis)
# Turn 50: Best Ball = Timer Ball, Capture Rate = 98.66% (Low HP & Paralysis)
