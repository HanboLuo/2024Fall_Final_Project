# %%
from Simulation import *

"""
This notebook shows the scatter-plotted results of 20,000 simulations with a maximum of 50 turns.
"""
if __name__ == '__main__':
    main()
# Out:
# Simulating capture for Mewtwo at full HP:
# Poke Ball - Success Rate: 1.05%, Average Turns: 25.23
# Great Ball - Success Rate: 1.74%, Average Turns: 23.92
# Ultra Ball - Success Rate: 2.04%, Average Turns: 26.18
# Quick Ball - Success Rate: 1.23%, Average Turns: 25.26
# Timer Ball - Success Rate: 2.89%, Average Turns: 29.97
# Simulating capture for Mewtwo at low HP with paralysis:
# Poke Ball - Success Rate: 3.58%, Average Turns: 25.60
# Great Ball - Success Rate: 4.73%, Average Turns: 25.15
# Ultra Ball - Success Rate: 5.56%, Average Turns: 24.33
# Quick Ball - Success Rate: 3.63%, Average Turns: 25.17
# Timer Ball - Success Rate: 7.99%, Average Turns: 28.82
# Analyzing minimum cost for capturing Mewtwo:
# Poke Ball: Success Rate = 3.55%, Avg. Turns = 24.56, Avg. Cost = 4911.39
# Great Ball: Success Rate = 4.76%, Avg. Turns = 25.71, Avg. Cost = 15428.12
# Ultra Ball: Success Rate = 5.80%, Avg. Turns = 25.08, Avg. Cost = 20063.45
# ...
